# %% [markdown]
# # Face Landmark Detection

# %% [markdown]
# In Face detection we only find out the face location

# %% [markdown]
# ### Installing Face Recognition Library

# %%
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Downloading https://files.pythonhosted.org/packages/1e/95/f6c9330f54ab07bfa032bf3715c12455a381083125d8880c43cbe76bb3d0/face_recognition-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Collecting face-recognition-models>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/cf/3b/4fd8c534f6c0d1b80ce0973d01331525538045084c73c153ee6df20224cf/face_recognition_models-0.3.0.tar.gz (100.1MB)
#      |████████████████████████████████| 100.2MB 42kB/s
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=a81c3945d950d5fe2a6446ebf28f4a750ec92532aaa1bc3fa5e672de209e7b3b
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %% [markdown]
# ### Importing Required Modules

# %%
import PIL.Image
import PIL.ImageDraw
import face_recognition
import numpy as np
import requests
from io import BytesIO

# %% [markdown]
# ## Images to use for Testing
# https://images.pexels.com/photos/3184398/pexels-photo-3184398.jpeg?auto=compress&cs=tinysrgb&h=750&w=1260
# <br>
# https://images.pexels.com/photos/3184291/pexels-photo-3184291.jpeg?auto=compress&cs=tinysrgb&h=750&w=1260
# <br>
# https://images.pexels.com/photos/3184360/pexels-photo-3184360.jpeg?auto=compress&cs=tinysrgb&h=750&w=1260
# <br>
# https://images.pexels.com/photos/3184351/pexels-photo-3184351.jpeg?auto=compress&cs=tinysrgb&h=750&w=1260
# <br>
# https://images.pexels.com/photos/3183172/pexels-photo-3183172.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940
# <br>
# https://images.pexels.com/photos/4428041/pexels-photo-4428041.jpeg?auto=compress&cs=tinysrgb&dpr=3&h=750&w=1260

# %% [markdown]
# #### To read image in files path

# %% [markdown]
# image = face_recognition.load_image_file('PATH HERE')

# %% [markdown]
# ### Read Image from Image URL

# %%
url = "https://images.pexels.com/photos/3184398/pexels-photo-3184398.jpeg?auto=compress&cs=tinysrgb&h=750&w=1260"

# %%
response = requests.get(url)
image = np.array(PIL.Image.open(BytesIO(response.content)))

# %% [markdown]
# ### Detect the faces in the Picture

# %% [markdown]
# It returns a list of detected faces with top, left, bottom and right pixel value of each face

# %%
face_landmarks = face_recognition.face_landmarks(image)

# %%
num_of_faces = len(face_landmarks)
print(f"Found {num_of_faces} number of faces in photo")
# Out:
# Found 6 number of faces in photo

# %% [markdown]
# ### Converting Array back to PIL Image

# %%
pil_image = PIL.Image.fromarray(image)

# %% [markdown]
# ### Make a PIL Draw Object

# %%
draw = PIL.ImageDraw.Draw(pil_image)

# %% [markdown]
# ### Drawing Rectangle for each Face

# %%
for face_landmark in face_landmarks:
  for name, list_of_points in face_landmark.items():
    print(f"The {name} in this image has the following points: {list_of_points}")

    draw.line(list_of_points, fill = "red", width = 2)
# Out:
# The chin in this image has the following points: [(418, 259), (419, 267), (419, 274), (420, 282), (424, 290), (430, 295), (438, 300), (446, 303), (455, 305), (464, 304), (472, 301), (479, 296), (484, 290), (487, 282), (488, 273), (489, 265), (489, 257)]
# The left_eyebrow in this image has the following points: [(423, 250), (426, 243), (432, 240), (439, 241), (445, 243)]
# The right_eyebrow in this image has the following points: [(458, 243), (465, 240), (472, 240), (479, 242), (483, 248)]
# The nose_bridge in this image has the following points: [(453, 250), (453, 254), (453, 258), (454, 263)]
# The nose_tip in this image has the following points: [(446, 269), (450, 269), (454, 270), (458, 269), (462, 269)]
# The left_eye in this image has the following points: [(430, 252), (434, 250), (439, 250), (443, 253), (439, 253), (434, 253)]
# The right_eye in this image has the following points: [(463, 252), (467, 249), (471, 249), (475, 251), (472, 251), (468, 252)]
# The top_lip in this image has the following points: [(436, 280), (442, 276), (449, 274), (454, 274), (459, 274), (466, 276), (473, 280), (471, 280), (459, 277), (454, 277), (449, 277), (438, 280)]
# The bottom_lip in this image has the following points: [(473, 280), (466, 285), (459, 287), (454, 288), (449, 287), (442, 285), (436, 280), (438, 280), (449, 283), (454, 283), (459, 283), (471, 280)]
# The chin in this image has the following points: [(750, 225), (752, 231), (754, 238), (757, 245), (761, 251), (766, 255), (774, 257), (783, 257), (793, 256), (802, 254), (810, 251), (817, 247), (821, 240), (822, 232), (822, 223), (821, 214), (819, 206)]
# The left_eyebrow in this image has the following points: [(752, 209), (755, 204), (759, 201), (765, 199), (772, 198)]
# The right_eyebrow in this image has the following points: [(783, 195), (789, 191), (796, 189), (803, 190), (810, 194)]
# The nose_bridge in this image has the following points: [(780, 203), (781, 206), (783, 210), (784, 214)]
# The nose_tip in this image has the following points: [(779, 224), (783, 223), (786, 222), (789, 221), (792, 220)]
# The left_eye in this image has the following points: [(759, 213), (762, 210), (766, 208), (771, 209), (767, 211), (763, 213)]
